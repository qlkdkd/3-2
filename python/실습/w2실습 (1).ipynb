# %%
print(1+1)
# Out:
# 2

# %%
x=3
print(type(x==4))
# Out:
# <class 'bool'>

# %%
name="Jinu"
print("안녕하세요 제 이름은"+name+"입니다.")
print("안녕하세요 제 이름은" + name + "입니다.")
print("안녕하세요 제 이름은", name, '입니다.')
# Out:
# 안녕하세요 제 이름은Jinu입니다.
# 안녕하세요 제 이름은Jinu입니다.
# 안녕하세요 제 이름은 Jinu 입니다.

# %%
print('100'+'200')
print(100+200)
# Out:
# 100200
# 300

# %%
print('백'+100)
#str형과 int형은 서로 연산이 불가능함
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-e516cc669808> in <cell line: 1>()
# ----> 1 print('백'+100)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('백'+'100')
# Out:
# 백100

# %%
sentence="this is 'python for AI' class"
print(sentence)
# Out:
# this is 'python for AI' class

# %%
#sentence="this is "python for AI"class" 에러!!!
sentence="this is \"python for AI\" class"
print(sentence)
# Out:
# this is "python for AI" class

# %%
#변수
x=3
y=5.0
sum_xy=x+y
print(sum_xy)
# Out:
# 8.0

# %%
sum_str=str(sum_xy)
print(type(sum_str))
# Out:
# <class 'str'>

# %% [markdown]
# ## input 함수

# %%
name=input("이름을 입력하시오: ")
# Out:
# 이름을 입력하시오: 신대한

# %%
print(name)
# Out:
# 신대한

# %% [markdown]
# 유의사항: input함수는 str형태로 받아들임

# %%
num=input("숫자 입력: ")
print(type(num))

num2=int(input("숫자 입력: "))
print(type(num2))
# Out:
# 숫자 입력: 123
# <class 'str'>
# 숫자 입력: 123
# <class 'int'>

# %% [markdown]
# ## 터틀 그래픽

# %%
# !pip install ColabTurtle

# %%
from ColabTurtle.Turtle import *

# %%
initializeTurtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
left(90)
right(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
x=100
forward(x)
left(120)
forward(x)
left(120)
forward(x)
left(120)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.397" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="200.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
initializeTurtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
initializeTurtle()

color('mediumblue')
penup()
goto(100, 100)
goto(100, 200)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,100,200) translate(82, 182)">
# ...

# %%
initializeTurtle()

#신
#ㅅ
penup()
goto(100, 100)
pendown()
left(150)
forward(100)

penup()
goto(100, 100)
pendown()
left(60)
forward(100)

#ㅣ
penup()
goto(200, 100)
left(150)
left(180)
pendown()
forward(100)

#ㄴ
penup()
goto(100, 250)
pendown()
forward(50)
left(90)
forward(100)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="100" y1="100" x2="50.0" y2="186.603" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="100" y1="100" x2="150.0" y2="186.603" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200" y1="100" x2="200.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="100" y1="250" x2="100.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="100.0" y1="300.0" x2="200.0" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(90,200.0,300.0) translate(182.0, 282.0)">
# ...

# %%
#대
#ㄷ

penup()
goto(300, 100)
pendown()
forward(100)
penup()
right(90)
forward(50)
initializeTurtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
